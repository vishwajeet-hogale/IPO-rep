# %% [markdown]
# <a href="https://colab.research.google.com/github/vishwajeet-hogale/IPO-rep/blob/main/Italian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import datetime

# %%
url = 'https://www.reuters.com/search/news?blob=IPO'

url1 = 'https://www.reuters.com'
page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')

# print(soup)



links = []
# print(soup.find_all('article', {'class': 'art_item'}))
for i in soup.find_all('h3',{"class":"search-result-title"}):

 
    
  try:
    if(str(i.a["href"]).startswith("/")):
      links.append(url1+i.a["href"])
    else:
      links.append(i.a["href"])
      print(i)
  # print(i)
  except:
    continue

# links.append(a["href"])
print(links)

title = []
date = []
s_date = []
text = []

for l in links:
  try:
    # print(l)
    fetch = requests.get(l)
    
    sp = BeautifulSoup(fetch.content, 'html.parser')
    # print(sp)
    x=sp.find("h1", { "class" : "Headline-headline-2FXIq Headline-black-OogpV ArticleHeader-headline-NlAqj" }).text
    # print(x)
    title.append(x)
      
      
    y = datetime.datetime.now()


    
    z = sp.find("div", { "class" : "ArticleBodyWrapper" }).text
    print(z)
    text.append(z)

    # y = pattern.match(z)
    # print(y)
  
    date.append(y)
    
    
  except:
    continue
  


df2 = pd.DataFrame(list(zip(title,links,date,text)), 
        columns =['title', 'link','publish_date','text'])


df2.to_csv('italian.csv')
# Out:
# ['https://www.reuters.com/article/idUSASN000W9C', 'https://www.reuters.com/article/idUSL4N2FU4MV', 'https://www.reuters.com/article/idUSKBN26M5MJ', 'https://www.reuters.com/article/idUSL4N2GY3AH', 'https://www.reuters.com/article/idUSL4N2IN3B1', 'https://www.reuters.com/article/idUSL4N2K43EI', 'https://www.reuters.com/article/idUSKBN27E01Y', 'https://www.reuters.com/article/idUSL4N2GF3N7', 'https://www.reuters.com/article/idUSKBN25S5UG', 'https://www.reuters.com/article/idUSKBN27T1ZP']
# ...
