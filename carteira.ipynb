# %% [markdown]
# <a href="https://colab.research.google.com/github/vishwajeet-hogale/IPO-rep/blob/main/carteira.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newspaper3k

# %%
import pandas as pd
import time
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import pandas as pd 
import html
from datetime import datetime

# %%
urls = "https://carteirasa.com.br/?s=Ipo"
def get_links(urls):
  
  links = [] 
  page=requests.get(urls)
  soup=BeautifulSoup(page.content,'html')
  divs = soup.find_all('div',{'class':'item-mid'})
  for i in divs:
    links.append(i.a["href"])
  return links

# %%
title=[]
link=[]
pub_date=[]
scraped_date=[]
links1 = get_links(urls)

# %%
len(links1)
# Out:
# 17

# %%
body = [] 
link = []
date = []
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
from newspaper import Article
for ur in links1:
  print(ur)
  try:
    article = Article(ur)
    article.download()
    article.parse()
    # print(article.text)
    
    link.append(ur)
    scraped_date.append(current_time)
    body.append(article.text)
    title.append(article.title)
    
    date.append(article.publish_date)

  except:
    
    continue
  time.sleep(0.5)
# Out:
# https://carteirasa.com.br/ipo-smartfit-smft3/
# https://carteirasa.com.br/csn-cimentos-controlada-da-csn-csna3-pede-registro-de-ipo/
# https://carteirasa.com.br/cba-companhia-brasileira-aluminio-ipo/
# https://carteirasa.com.br/invest-tech-ipo/
# https://carteirasa.com.br/ipo-multilaser/
# https://carteirasa.com.br/ipo-getninjas-ninj3/
# https://carteirasa.com.br/ipo-g2d-investments-g2di/
# https://carteirasa.com.br/g2d-investments-g2di-inicia-periodo-de-reserva-de-ipo/
# https://carteirasa.com.br/g2d-investments-g2di33-estreia-bolsa/
# https://carteirasa.com.br/grupo-mateus-gmat3-balanco-1t21/
# https://carteirasa.com.br/triunfo-tpis3-balanco-1t21/
# https://carteirasa.com.br/alupar-alup11-oferta-secundaria-acoes-fgts/
# https://carteirasa.com.br/vittia-vitt3-ipo/
# https://carteirasa.com.br/mater-dei-matd3-estreia-bolsa/
# https://carteirasa.com.br/cielo-ciel3-renuncia-ceo-caffarelli/
# https://carteirasa.com.br/petz-petz3-e-odontoprev-odpv3-informam-dividendos/
# ...

# %%
df = pd.DataFrame({"Article":body,"Link":link,"Publish Date":date,"Scrape Date":scraped_date,"Title":title})

# %%
df
# Out:
#                                               Article  ...                                              Title
# 0   A SmartFit (SMFT3) protocolou nesta terça-feir...  ...           SmartFit (SMFT3) protocola pedido de IPO
# 1   A CSN Cimentos, controlada da CSN (CSNA3), pro...  ...  CSN Cimentos, controlada da CSN (CSNA3), pede ...
# 2   A Companhia Brasileira de Alumínio (CBA) proto...  ...  CBA, Companhia Brasileira de Alumínio, pede re...
# 3   A Invest Tech protocolou nesta segunda-feira (...  ...                   Invest Tech pede registro de IPO
# 4   A Multilaser protocolou pedido de oferta públi...  ...                 Multilaser protocola pedido de IPO
# 5   A GetNinjas (NINJ3) levantou R$ 554,3 milhões ...  ...       GetNinjas (NINJ3) movimenta R$ 554 mi em IPO
# 6   A G2D Investments (G2DI) levantou R$ 299 milhõ...  ...  G2D Investments (G2DI) capta quase R$ 300 mi e...
# ...
