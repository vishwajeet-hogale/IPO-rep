# %% [markdown]
# <a href="https://colab.research.google.com/github/vishwajeet-hogale/IPO-rep/blob/main/bisnis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newspaper3k
# Out:
# ...
#      |████████████████████████████████| 215kB 35.0MB/s
# ...
#      |████████████████████████████████| 81kB 10.6MB/s
# ...
#      |████████████████████████████████| 7.4MB 44.1MB/s
# ...
#      |████████████████████████████████| 92kB 12.4MB/s
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-cp37-none-any.whl size=13538 sha256=54c1d00d3a17f6c2f9d24cef666339ef9cb493e9825b6040e1851a8c6053d637
#   Stored in directory: /root/.cache/pip/wheels/81/2b/43/a02ede72324dd40cdd7ca53aad718c7710628e91b8b0dc0f02
# ...
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-cp37-none-any.whl size=7398406 sha256=782c8c5e403d00a92e9cd474684bc07b0504b6d6122d3bf1366526f305d93134
#   Stored in directory: /root/.cache/pip/wheels/83/15/9c/a3f1f67e7f7181170ad37d32e503c35da20627c013f438ed34
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-cp37-none-any.whl size=3358 sha256=3ae493c381ad7c46b4efd7554655ccdd9e03b0d0a5d03a6c6a88edb11da64dad
# ...

# %%
import pandas as pd
import time
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import pandas as pd 
import html
from datetime import datetime

# %%
urls = "https://search.bisnis.com/?q=IPO"
def get_links(urls):
  
  links = [] 
  page=requests.get(urls)
  soup=BeautifulSoup(page.content,'html')
  divs = soup.find_all('div',{'class':'col-sm-8'})
  for i in divs:
    links.append(i.h2.a["href"])
  return links

# %%
title=[]
link=[]
pub_date=[]
scraped_date=[]
links1 = get_links(urls)

# %%
len(links1)
# Out:
# 10

# %%
body = [] 
link = []
date = []
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
from newspaper import Article
for ur in links1:
  print(ur)
  try:
    article = Article(ur)
    article.download()
    article.parse()
    # print(article.text)
    
    link.append(ur)
    scraped_date.append(current_time)
    body.append(article.text)
    title.append(article.title)
    
    date.append(article.publish_date)

  except:
    
    continue
  time.sleep(0.5)
# Out:
# https://market.bisnis.com/read/20210519/7/1395658/dipakai-warren-buffett-google-dcs-muluskan-ipo-goto
# https://market.bisnis.com/read/20210519/192/1395626/penawaran-obligasi-adhi-commuter-properti-ludes-rp500-miliar-tahun-ini-lanjut-ipo
# https://kalimantan.bisnis.com/read/20210519/408/1395523/sbm-laksanakan-mini-expose-sebagai-tahapan-ipo
# https://finansial.bisnis.com/read/20210519/55/1395477/goto-akan-ipo-ini-5-tips-investasi-memilih-saham-ipo
# https://market.bisnis.com/read/20210519/7/1395467/lo-kheng-hong-sudah-20-tahun-saya-gak-beli-saham-ipo
# https://market.bisnis.com/read/20210519/189/1395344/pesona-emiten-toto-sugiri-tantangan-ipo-goto-dari-bursa
# https://market.bisnis.com/read/20210519/192/1395341/bos-wework-klaim-permintaan-sewa-melampaui-level-sebelum-pandemi
# https://koran.bisnis.com/read/20210519/244/1395311/merger-gojektokopedia-tanda-tanya-di-balik-goto
# https://market.bisnis.com/read/20210518/7/1395264/nunggu-ipo-goto-begini-cara-beli-saham-ipo-secara-online
# ...

# %%
df = pd.DataFrame({"Article":body,"Link":link,"Publish Date":date,"Scrape Date":scraped_date,"Title":title})

# %%
df
# Out:
#                                              Article  ...                                              Title
# 0                                                     ...  Dipakai Warren Buffett & Google, DCS Muluskan ...
# 1                                                     ...  Penawaran Obligasi Adhi Commuter Properti Lude...
# 2                                                     ...     SBM Laksanakan Mini Expose Sebagai Tahapan IPO
# 3                                                     ...  GoTo Akan IPO? Ini 5 Tips Investasi Memilih Sa...
# 4  Bisnis.com, JAKARTA - Lo Kheng Hong, investor ...  ...  Lo Kheng Hong: Sudah 20 Tahun Saya Gak Beli Sa...
# 5                                                     ...  Pesona Emiten Toto Sugiri & Tantangan IPO GoTo...
# 6                                                     ...  Bos WeWork Klaim Permintaan Sewa Melampaui Lev...
# 7                                                     ...  MERGER GOJEK—TOKOPEDIA : Tanda Tanya di Balik ...
# ...

# %%
df.to_csv("Scraped.csv")
