# %% [markdown]
# <a href="https://colab.research.google.com/github/vishwajeet-hogale/IPO-rep/blob/main/space_money.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newspaper3k
# Out:
# ...
#      |████████████████████████████████| 215kB 5.2MB/s
# ...
#      |████████████████████████████████| 81kB 4.8MB/s
# ...
#      |████████████████████████████████| 92kB 5.3MB/s
# ...
#      |████████████████████████████████| 7.4MB 6.7MB/s
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-cp37-none-any.whl size=3358 sha256=92b5852f969b14f34fd51f752790b2d93a7fdd672287de7b2a4d8d4ca0e3062d
#   Stored in directory: /root/.cache/pip/wheels/de/03/ca/778e3a7a627e3d98836cc890e7cb40c7575424cfd3340f40ed
# ...
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-cp37-none-any.whl size=7398406 sha256=420c1c711ec2c0710faaed4a49f30f0e3b6c360d143ddd467ba816d888adaf3e
#   Stored in directory: /root/.cache/pip/wheels/83/15/9c/a3f1f67e7f7181170ad37d32e503c35da20627c013f438ed34
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-cp37-none-any.whl size=13538 sha256=30239b3f77bb79f52533de8be56f5f21764d0330f58a3b007d99c824491cbf2b
# ...

# %%
import pandas as pd
import time
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import pandas as pd 
import html
from datetime import datetime

# %%
urls = "https://www.spacemoney.com.br/noticias/ipos/"
def get_links(urls):
  
  links = [] 
  page=requests.get(urls)
  soup=BeautifulSoup(page.content,'html')
  divs = soup.find_all('div',{'class':'linkNoticia crop'})
  for i in divs:
    links.append(i.a["href"])
  return links

# %%
title=[]
link=[]
pub_date=[]
scraped_date=[]
links1 = get_links(urls)

# %%
len(links1)
# Out:
# 16

# %%
body = [] 
link = []
date = []
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
from newspaper import Article
for ur in links1:
  print(ur)
  try:
    article = Article(ur)
    article.download()
    article.parse()
    # print(article.text)
    
    link.append(ur)
    scraped_date.append(current_time)
    body.append(article.text)
    title.append(article.title)
    
    date.append(article.publish_date)

  except:
    
    continue
  time.sleep(0.5)
# Out:
# https://www.spacemoney.com.br/noticias/ipos/cba-do-grupo-votorantim-protocola-pedido-de-ipo-na-comissao-de/165965/
# https://www.spacemoney.com.br/noticias/ipos/invest-tech-protocola-pedido-de-ipo-na-comissao-de-valores-mobiliarios/165928/
# https://www.spacemoney.com.br/noticias/ipos/multilaser-protocola-pedido-de-ipo-na-comissao-de-valores-mobiliarios/165927/
# https://www.spacemoney.com.br/noticias/ipos/csn-protocola-pedido-de-registro-de-ipo-do-seu-braco-de-cimentos/165920/
# https://www.spacemoney.com.br/geral/acoes-da-getninjas-ninj3-estreiam-na-b3-em-queda/165881/
# https://www.spacemoney.com.br/geral/getninjas-precifica-ipo-a-r-20-e-movimenta-r-554-milhoes/165828/
# https://www.spacemoney.com.br/geral/dotz-interrompe-ipo/165789/
# https://www.spacemoney.com.br/geral/unifique-telecomunicacoes-pede-registro-de-ipo/165769/
# https://www.spacemoney.com.br/geral/armac-empresa-locadora-de-equipamentos-pede-registro-de-ipo-a-cvm/165713/
# ...

# %%
df = pd.DataFrame({"Article":body,"Link":link,"Publish Date":date,"Scrape Date":scraped_date,"Title":title})

# %%
df
# Out:
#                                               Article  ...                                              Title
# 0   Nesta terça-feira (18), a Companhia Brasileira...  ...  CBA, do Grupo Votorantim, protocola pedido de ...
# 1   A Invest Tech pediu nesta segunda-feira (17) r...  ...  Invest Tech protocola pedido de IPO na Comissã...
# 2   A Multilaser, empresa que atua no segmento de ...  ...  Multilaser protocola pedido de IPO na Comissão...
# 3   A Companhia Siderúrgica Nacional (CSN) protoco...  ...  CSN protocola pedido de registro de IPO do seu...
# 4   As ações da GetNinjas, plataforma de serviços ...  ...  Ações da GetNinjas (NINJ3) estreiam na B3 em q...
# 5   A GetNinjas precificou as ações de seu IPO (of...  ...  GetNinjas precifica IPO a R$ 20 e movimenta R$...
# 6   A Dotz realizou um pedido de interrupção em se...  ...                                Dotz interrompe IPO
# ...
